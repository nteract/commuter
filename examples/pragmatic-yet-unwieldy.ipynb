# %%
from IPython.display import HTML, Markdown
import dx
import pandas as pd
import numpy as np

display(Markdown("""
# Pragmatic Yet Unwieldy Notebook

_Unnamed Notebook Author_

2018
"""))

print("Mixed media; HTML, Markdown, Tabular data, maybe Vega\n")

display(HTML("""
A daring interpretative piece, <i>Pragmatic Yet Unwieldy Notebook</i> was part of a series of strung together
outputs made in the fall of 2018. Critics suggested it is a commentary on modern life's obsession with the incessant
buzzing of the machines around us and our deep attempt to connect with other beings, be they human or machine. The partly
strung together notebook unashamedly displays the author's inability to break apart cells into discrete chunks, daring the
nteract contributors to criticism.
"""))

df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))

dx.enable()
display(df)
dx.disable()

print("tensorflow likes to mix diagnostic noise amidst your useful outputs "*100)
# Out:
# # Pragmatic Yet Unwieldy Notebook
#
# _Unnamed Notebook Author_
#
# 2018
# Mixed media; HTML, Markdown, Tabular data, maybe Vega
# A daring interpretative piece, <i>Pragmatic Yet Unwieldy Notebook</i> was part of a series of strung together
# outputs made in the fall of 2018. Critics suggested it is a commentary on modern life's obsession with the incessant
# buzzing of the machines around us and our deep attempt to connect with other beings, be they human or machine. The partly
# strung together notebook unashamedly displays the author's inability to break apart cells into discrete chunks, daring the
# nteract contributors to criticism.
#      A   B   C   D
# 0   16  28  11  62
# 1   69  23  80  34
# 2   38  69   0  88
# 3   56  67  40  78
# 4   19  28  89   5
# 5   32  44  36  13
# 6   79  34   8  26
# 7   41  25  48  58
# 8   41   2  26  94
# 9   42  12  23  93
# 10  36  22  89  14
# 11  81   5  36  72
# 12  46   1  21  39
# 13  44  79  78  53
# 14  12  38  78  42
# ...
